# %%
from gurobipy import Model, GRB
import pandas as pd

# Load data from CSV files
demand_nodes = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day1_1.csv")
demand_truck = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day1_3.csv")
problem_data = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day1_2.csv")
truck_nodes = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day1_4.csv")

# Convert truck identifiers to string for consistency
demand_truck['truck_node_index'] = demand_truck['truck_node_index'].astype(str)
truck_nodes['index'] = truck_nodes['index'].astype(str)

# Extract costs and parameters
burrito_price = problem_data['burrito_price'][0]
ingredient_cost = problem_data['ingredient_cost'][0]
truck_cost = problem_data['truck_cost'][0]

# Create a Gurobi Model
model = Model("Optimal_Truck_Location")

# Decision Variables: Assign trucks to demand locations
x = model.addVars(demand_truck.index, vtype=GRB.BINARY, name="assign")  # 1 if demand node is served by truck
y = model.addVars(truck_nodes['index'], vtype=GRB.BINARY, name="use_truck")  # 1 if truck is used

# Objective Function: Maximize Profit
model.setObjective(
    sum(x[i] * ((burrito_price - ingredient_cost) * demand_truck.loc[i, 'scaled_demand']) for i in demand_truck.index)
    - sum(y[j] * truck_cost for j in truck_nodes['index']),  # Truck cost applied only if the truck is used
    GRB.MAXIMIZE
)

# Constraints: Ensure each demand node is served exactly once
for demand in demand_nodes['index']:
    model.addConstr(
        sum(x[i] for i in demand_truck.index if demand_truck.loc[i, 'demand_node_index'] == demand) == 1, 
        name=f"demand_fulfillment_{demand}"
    )

# Ensure that a truck is marked as "used" if it's assigned to at least one demand node
for j in truck_nodes['index']:
    if j in demand_truck['truck_node_index'].values:  # Ensure truck exists in demand_truck dataset
        model.addConstr(
            sum(x[i] for i in demand_truck.index if demand_truck.loc[i, 'truck_node_index'] == j) <= y[j] * len(demand_nodes),
            name=f"truck_usage_{j}"
        )

# Optimize the Model
model.optimize()

# Print the Total Profit
if model.status == GRB.OPTIMAL:
    print(f"Total Profit: {model.ObjVal}")
    
    # Debugging Output: Check how many trucks are used
    total_trucks_used = sum(y[j].x for j in truck_nodes['index'])
    print(f"Total Trucks Used: {total_trucks_used}")
    
    # Check total demand met
    total_demand_met = sum(demand_truck.loc[i, 'scaled_demand'] for i in demand_truck.index if x[i].x > 0.5)
    print(f"Total Demand Met: {total_demand_met}")
    
    optimal_assignments = {
        demand_truck.loc[i, 'demand_node_index']: demand_truck.loc[i, 'truck_node_index']
        for i in demand_truck.index if x[i].x > 0.5
    }
    print("\nOptimal Truck Assignments:")
    for demand, truck in optimal_assignments.items():
        print(f"Demand Node {demand} is served by Truck {truck}")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 24.3.0 24D81)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 35 rows, 324 columns and 630 nonzeros
# Model fingerprint: 0xcda84dfa
# Variable types: 0 continuous, 324 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [5e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -2850.000000
# Presolve time: 0.00s
# Presolved: 35 rows, 324 columns, 630 nonzeros
# Variable types: 0 continuous, 324 integer (324 binary)
#
# Root relaxation: objective 1.405000e+03, 17 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1405.00000    0    9 -2850.0000 1405.00000   149%     -    0s
# H    0     0                    -595.0000000 1405.00000   336%     -    0s
# H    0     0                    -445.0000000 1405.00000   416%     -    0s
# H    0     0                    -350.0000000 1405.00000   501%     -    0s
# H    0     0                    -105.0000000 1405.00000  1438%     -    0s
# H    0     0                      75.0000000 1405.00000  1773%     -    0s
# H    0     0                     310.0000000 1097.76162   254%     -    0s
# H    0     0                     320.0000000 1097.76162   243%     -    0s
#      0     0 1097.76162    0   29  320.00000 1097.76162   243%     -    0s
# H    0     0                     370.0000000 1084.57778   193%     -    0s
# H    0     0                     495.0000000 1016.76471   105%     -    0s
#      0     0 1016.76471    0   35  495.00000 1016.76471   105%     -    0s
# H    0     0                     510.0000000 1016.76471  99.4%     -    0s
#      0     0  985.00000    0   24  510.00000  985.00000  93.1%     -    0s
# H    0     0                     520.0000000  985.00000  89.4%     -    0s
# H    0     0                     725.0000000  971.17647  34.0%     -    0s
#      0     0  966.19485    0   27  725.00000  966.19485  33.3%     -    0s
# H    0     0                     885.0000000  900.90074  1.80%     -    0s
#      0     0  900.90074    0    4  885.00000  900.90074  1.80%     -    0s
#
# Cutting planes:
#   Cover: 20
#   Clique: 6
#   MIR: 8
#   StrongCG: 1
#
# Explored 1 nodes (73 simplex iterations) in 0.03 seconds (0.01 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 885 725 520 ... -105
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.850000000000e+02, best bound 8.850000000000e+02, gap 0.0000%
# Total Profit: 885.0
# Total Trucks Used: 2.0
# Total Demand Met: 277
#
# Optimal Truck Assignments:
# Demand Node demand2 is served by Truck truck17
# Demand Node demand11 is served by Truck truck17
# Demand Node demand12 is served by Truck truck17
# Demand Node demand13 is served by Truck truck17
# Demand Node demand14 is served by Truck truck17
# Demand Node demand18 is served by Truck truck17
# Demand Node demand19 is served by Truck truck38
# Demand Node demand21 is served by Truck truck17
# Demand Node demand22 is served by Truck truck17
# Demand Node demand28 is served by Truck truck38
# Demand Node demand29 is served by Truck truck38
# Demand Node demand32 is served by Truck truck38
# Demand Node demand34 is served by Truck truck17
# Demand Node demand40 is served by Truck truck17
# Demand Node demand41 is served by Truck truck38
# Demand Node demand45 is served by Truck truck38
# Demand Node demand51 is served by Truck truck17

# %%
from gurobipy import Model, GRB
import pandas as pd
import os

# Load data from CSV files
demand_nodes = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day2_1.csv")
demand_truck = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day2_3.csv")
truck_nodes = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day2_4.csv")

# Verify available files in the directory
folder_path = "/Users/pavanvinayveesam/downloads/"
print("Files in directory:", os.listdir(folder_path))

# Load problem data CSV, ensuring the correct file is used
try:
    problem_data = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day2_2.csv")
    print("Columns in problem_data before processing:", problem_data.columns)
except FileNotFoundError:
    raise FileNotFoundError("The problem_data.csv file is missing. Ensure the correct file is present in the directory.")

# Ensure 'burrito_price' column exists
if "burrito_price" not in problem_data.columns:
    raise KeyError(f"'burrito_price' column is missing! Available columns: {problem_data.columns}")

# Convert truck identifiers to string for consistency
demand_truck["truck_node_index"] = demand_truck["truck_node_index"].astype(str)
truck_nodes["index"] = truck_nodes["index"].astype(str)

# Extract cost parameters
burrito_price = problem_data["burrito_price"][0]
ingredient_cost = problem_data["ingredient_cost"][0]
truck_cost = problem_data["truck_cost"][0]

# Create a Gurobi model
model = Model("Optimal_Truck_Location")

# Decision Variables
x = model.addVars(demand_truck.index, vtype=GRB.BINARY, name="assign")  # 1 if demand node is served by truck
y = model.addVars(truck_nodes["index"], vtype=GRB.BINARY, name="use_truck")  # 1 if truck is used

# Objective Function: Maximize Profit
model.setObjective(
    sum(x[i] * ((burrito_price - ingredient_cost) * demand_truck.loc[i, "scaled_demand"]) for i in demand_truck.index)
    - sum(y[j] * truck_cost for j in truck_nodes["index"]),  # Truck cost applied only if the truck is used
    GRB.MAXIMIZE
)

# Constraints: Ensure each demand node is served exactly once
for demand in demand_nodes["index"]:
    model.addConstr(
        sum(x[i] for i in demand_truck.index if demand_truck.loc[i, "demand_node_index"] == demand) == 1, 
        name=f"demand_fulfillment_{demand}"
    )

# Ensure that a truck is marked as "used" if it's assigned to at least one demand node
for j in truck_nodes["index"]:
    if j in demand_truck["truck_node_index"].values:  # Ensure truck exists in demand_truck dataset
        model.addConstr(
            sum(x[i] for i in demand_truck.index if demand_truck.loc[i, "truck_node_index"] == j) <= y[j] * len(demand_nodes),
            name=f"truck_usage_{j}"
        )

# Optimize the Model
model.optimize()

# Print the Total Profit
if model.status == GRB.OPTIMAL:
    print(f"Total Profit: {model.ObjVal}")
    
    # Debugging Output: Check how many trucks are used
    total_trucks_used = sum(y[j].x for j in truck_nodes["index"])
    print(f"Total Trucks Used: {total_trucks_used}")
    
    # Check total demand met
    total_demand_met = sum(demand_truck.loc[i, "scaled_demand"] for i in demand_truck.index if x[i].x > 0.5)
    print(f"Total Demand Met: {total_demand_met}")
    
    optimal_assignments = {
        demand_truck.loc[i, "demand_node_index"]: demand_truck.loc[i, "truck_node_index"]
        for i in demand_truck.index if x[i].x > 0.5
    }
    
    print("\nOptimal Truck Assignments:")
    for demand, truck in optimal_assignments.items():
        print(f"Demand Node {demand} is served by Truck {truck}")
else:
    print("No optimal solution found.")
# Out:
# Files in directory: ['BAN 675-01_Text Mining_2025Spring-1.pdf', 'Lecture_pandas.ipynb', 'Bank OZK Resume.pdf', 'Budgeting in class(1).ipynb', 'Advt to class (5).ipynb', 'HW 3 (1).xlsx', 'summer_analyst_resume.docx', 'InstallLDBPackage64c-2-1-2-08.zip', 'BAN 630_Chap 7 notes (2).pdf', '1737353558199 (1).docx', 'Pavan Vinay Veesam - Banker Development Program Resume.pdf', '1741330488026.pdf', 'Rougir_Cosmetics_Solution.xlsx', 'MS_SQL_SERVER_Installation_on_Windows-1.docx', 'Install Respondus LockDown Browser (x64c) 663347111 2.pkg', 'CCFBank_Resume.docx', 'Associate Financial Analyst.pdf', 'PavanVinay_Financial_Analyst_Resume (10).pdf', 'BankScheduling (1).ipynb', 'ban612finalprojectsubmissiongroup3', 'BAN 630_Chap 6 (6 slides).pdf', 'Account_Analyst.pdf', 'GMT20241025-010048_Recording.transcript.vtt', 'round1-day1_problem_data.csv', 'annotated-Big%20Data%20Assignment%2001.docx.pdf', 'GMT20241025-010048_Recording.cc.vtt', 'TransMedics_Resume.docx', 'annotated-Case%204.docx.pdf', 'codebasics-movies-db.sql', '630_intro_LP.xlsx', 'PavanVinay_Edited_Resume (3) (1).docx', 'Final_Exam (1).ipynb', 'PavanVinay_Financial_Analyst_Resume (8).docx', 'Resume_PavanVinay_Veesam.pdf', 'Install Respondus LockDown Browser (x64c) 663347111 3.pkg', 'Resume_Financial_Analyst (1).pdf', 'GMT20241018-010406_Recording.transcript (1).vtt', 'GMT20240904-010516_Recording (1).m4a', 'GMT20240918-011014_Recording.cc.vtt', 'PdtMix with SA(1) (2) (1).ipynb', ' Barclays Resume.docx', 'Social Impact Innovation Intern.pdf', '173895233795234 (1).docx', 'Advt.ipynb', 'Financial_Analyst_Resume_PavanVinay (1).docx', 'Rougir_Cosmetics_Solver_Setup.xlsx', 'Crédit Agricole CIB_Resume.docx', 'Data_Mining', 'day1_4.csv', 'Resume_PavanVinayVeesam (10).docx', 'Pavan Vinay Veesam - Intern Resume-cover-letter.pdf', 'ATM and Bumper in class (1).ipynb', 'git-course-2 2', 'BAN630-HW4.ipynb', 'Financial_Analyst_Resume_PavanVinay (3).docx', 'BAN 630_Chap 4 (6).pdf', 'GMT20241018-010406_RecordingnewChat.txt', 'pexels-jonathanschmer-2602599.jpg', 'round1-day1_truck_node_data.csv', 'GMT20240904-010516_RecordingnewChat (1).txt', 'Resume_PavanVinayVeesam (2).docx', 'Graduate_Intern.docx', 'Cover_Letter_Pavan_Vinay_Veesam (1).pdf', 'Data_Analyst_Resume (1).docx', 'PavanVinayVeesam_Financial_Analyst_Resume (1).pdf', 'veesam_pavan_vinay_resume (4) (5).pdf', 'Data Loading.pptx', 'BAN 620_2024_Fall_Syllabus 2-1 (3).pdf', 'Commercial Credit Analyst Intern .docx', 'HW 1 (1).pdf', 'online_retail_II 7.xlsx', 'CourseOverview-BAN622-1-1.pptx', 'Cover_Letter_Pavan_Vinay_Veesam.pdf', 'Pavan Vinay Veesam Resume-cover-letter.pdf', '1738886721889.docx', 'CV.docx', 'Travel Reservation December 18 for PAVAN VINAY VEESAM (1).pdf', '1737353558199.pdf', 'annotated-BAN%20620%28Data%20mining%29%20final%20project.pdf', 'BAN 620_2024_Fall_Syllabus 2-1.pdf', 'Summer_Intern.docx', 'GMT20241018-010406_Recording_2160x1440.mp4', 'IMG-20250205-WA0003.jpg', 'Advt to class.ipynb', 'BAN 620_Chap14 ARCF.pdf', 'PavanVinayVeesam_Resume.pdf', 'OFA Company Values - Final 8-7-23.pdf', 'NLP.xlsx', 'BAN 620(Data mining) final project (4).ipynb', 'GMT20241018-010406_Recording.m4a', 'Chapter04 (1).pptx', 'GMT20241025-010048_Recording_2160x1440.mp4', 'MS_SQL_SERVER_Installation_on_Mac-1.docx', 'BAN 630_Chap 6 (1).pdf', 'PavanVinay_Edited_Resume (10) (1).pdf', 'GMT20240911-010400_RecordingnewChat.txt', 'chunking.py', 'First Horizon Bank_Resume.docx', 'mysql-workbench-community-8.0.40-macos-arm64.dmg', 'SQL Server Driver for Mac.pkg', 'HW 4 (2).pdf', 'IMG_20250217_111153585.jpg', 'PavanVinay_Edited_Resume (1).pdf', 'Nightwing Resume.docx', 'Pavan Vinay Veesam - Financial Analyst Resume-cover-letter.pdf', 'GMT20240904-010516_Recording_1600x800 (2).mp4', 'Business Recommendations for Hiland.docx', 'Claims Intern.docx', 'Warehouse (3).ipynb', 'Reworld_Waste_Resume.docx', '1234.docx', 'Financial_Analyst_Resume_PavanVinay (13).docx', 'DOC-20250213-WA0006 (2)', 'Case4 (2).ipynb', 'Resume_PavanVinayVeesam.docx', '1738715096899.pdf', 'day1 ...
# Columns in problem_data before processing: Index(['burrito_price', 'ingredient_cost', 'truck_cost'], dtype='object')
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 24.3.0 24D81)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 59 rows, 884 columns and 1742 nonzeros
# Model fingerprint: 0xaeb8b31d
# Variable types: 0 continuous, 884 integer (884 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [5e+00, 4e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -3040.000000
# Presolve time: 0.00s
# Presolved: 59 rows, 884 columns, 1742 nonzeros
# Variable types: 0 continuous, 884 integer (884 binary)
#
# Root relaxation: objective 6.730000e+03, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6730.00000    0   15 -3040.0000 6730.00000   321%     -    0s
# H    0     0                    3230.0000000 6730.00000   108%     -    0s
# H    0     0                    3705.0000000 6730.00000  81.6%     -    0s
# H    0     0                    3950.0000000 6730.00000  70.4%     -    0s
# H    0     0                    4180.0000000 6730.00000  61.0%     -    0s
# H    0     0                    4380.0000000 6730.00000  53.7%     -    0s
#      0     0 5654.08676    0   51 4380.00000 5654.08676  29.1%     -    0s
#      0     0 5638.39019    0   59 4380.00000 5638.39019  28.7%     -    0s
# H    0     0                    4385.0000000 5638.39019  28.6%     -    0s
#      0     0 5063.01516    0   57 4385.00000 5063.01516  15.5%     -    0s
# H    0     0                    4405.0000000 5059.84062  14.9%     -    0s
# H    0     0                    4445.0000000 5059.84062  13.8%     -    0s
#      0     0 5059.84062    0   55 4445.00000 5059.84062  13.8%     -    0s
#      0     0 4888.02216    0   45 4445.00000 4888.02216  10.0%     -    0s
# H    0     0                    4595.0000000 4888.02216  6.38%     -    0s
# H    0     0                    4605.0000000 4888.02216  6.15%     -    0s
# H    0     0                    4645.0000000 4888.02216  5.23%     -    0s
# H    0     0                    4650.0000000 4887.43519  5.11%     -    0s
#      0     0 4887.43519    0   47 4650.00000 4887.43519  5.11%     -    0s
# H    0     0                    4730.0000000 4887.43519  3.33%     -    0s
#      0     0 4839.48589    0   10 4730.00000 4839.48589  2.31%     -    0s
# *    0     0               0    4775.0000000 4775.00000  0.00%     -    0s
#
# Explored 1 nodes (330 simplex iterations) in 0.04 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 4775 4730 4650 ... 4380
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.775000000000e+03, best bound 4.775000000000e+03, gap 0.0000%
# Total Profit: 4775.0
# Total Trucks Used: 6.0
# Total Demand Met: 1255
#
# Optimal Truck Assignments:
# Demand Node demand2 is served by Truck truck12
# Demand Node demand9 is served by Truck truck17
# Demand Node demand11 is served by Truck truck17
# Demand Node demand12 is served by Truck truck12
# Demand Node demand13 is served by Truck truck17
# Demand Node demand14 is served by Truck truck12
# Demand Node demand15 is served by Truck truck23
# Demand Node demand17 is served by Truck truck23
# Demand Node demand18 is served by Truck truck23
# Demand Node demand19 is served by Truck truck23
# Demand Node demand20 is served by Truck truck23
# Demand Node demand21 is served by Truck truck17
# Demand Node demand22 is served by Truck truck17
# Demand Node demand25 is served by Truck truck34
# Demand Node demand26 is served by Truck truck34
# Demand Node demand28 is served by Truck truck23
# Demand Node demand29 is served by Truck truck38
# Demand Node demand31 is served by Truck truck38
# Demand Node demand32 is served by Truck truck38
# Demand Node demand33 is served by Truck truck38
# Demand Node demand34 is served by Truck truck34
# Demand Node demand35 is served by Truck truck34
# Demand Node demand37 is served by Truck truck43
# Demand Node demand38 is served by Truck truck34
# Demand Node demand40 is served by Truck truck43
# Demand Node demand41 is served by Truck truck43
# Demand Node demand45 is served by Truck truck38
# Demand Node demand46 is served by Truck truck38
# Demand Node demand47 is served by Truck truck34
# Demand Node demand48 is served by Truck truck17
# Demand Node demand50 is served by Truck truck17
# Demand Node demand51 is served by Truck truck17
# Demand Node demand53 is served by Truck truck12

# %%
from gurobipy import Model, GRB
import pandas as pd
import os

# Load data from CSV files
demand_nodes = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day2_1.csv")
demand_truck = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day2_3.csv")
truck_nodes = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day2_4.csv")

# Verify available files in the directory
folder_path = "/Users/pavanvinayveesam/downloads/"
print("Files in directory:", os.listdir(folder_path))

# Load problem data CSV, ensuring the correct file is used
try:
    problem_data = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day2_2.csv")
    print("Columns in problem_data before processing:", problem_data.columns)
except FileNotFoundError:
    raise FileNotFoundError("The problem_data.csv file is missing. Ensure the correct file is present in the directory.")

# Ensure 'burrito_price' column exists
if "burrito_price" not in problem_data.columns:
    raise KeyError(f"'burrito_price' column is missing! Available columns: {problem_data.columns}")

# Convert truck identifiers to string for consistency
demand_truck["truck_node_index"] = demand_truck["truck_node_index"].astype(str)
truck_nodes["index"] = truck_nodes["index"].astype(str)

# Extract cost parameters
burrito_price = problem_data["burrito_price"][0]
ingredient_cost = problem_data["ingredient_cost"][0]
truck_cost = problem_data["truck_cost"][0]

# Create a Gurobi model
model = Model("Optimal_Truck_Location")

# Decision Variables
x = model.addVars(demand_truck.index, vtype=GRB.BINARY, name="assign")  # 1 if demand node is served by truck
y = model.addVars(truck_nodes["index"], vtype=GRB.BINARY, name="use_truck")  # 1 if truck is used

# Objective Function: Maximize Profit
model.setObjective(
    sum(x[i] * ((burrito_price - ingredient_cost) * demand_truck.loc[i, "scaled_demand"]) for i in demand_truck.index)
    - sum(y[j] * truck_cost for j in truck_nodes["index"]),  # Truck cost applied only if the truck is used
    GRB.MAXIMIZE
)

# Constraints: Ensure each demand node is served exactly once
for demand in demand_nodes["index"]:
    model.addConstr(
        sum(x[i] for i in demand_truck.index if demand_truck.loc[i, "demand_node_index"] == demand) == 1, 
        name=f"demand_fulfillment_{demand}"
    )

# Ensure that a truck is marked as "used" if it's assigned to at least one demand node
for j in truck_nodes["index"]:
    if j in demand_truck["truck_node_index"].values:  # Ensure truck exists in demand_truck dataset
        model.addConstr(
            sum(x[i] for i in demand_truck.index if demand_truck.loc[i, "truck_node_index"] == j) <= y[j] * len(demand_nodes),
            name=f"truck_usage_{j}"
        )

# Optimize the Model
model.optimize()

# Print the Total Profit
if model.status == GRB.OPTIMAL:
    print(f"Total Profit: {model.ObjVal}")
    
    # Debugging Output: Check how many trucks are used
    total_trucks_used = sum(y[j].x for j in truck_nodes["index"])
    print(f"Total Trucks Used: {total_trucks_used}")
    
    # Check total demand met
    total_demand_met = sum(demand_truck.loc[i, "scaled_demand"] for i in demand_truck.index if x[i].x > 0.5)
    print(f"Total Demand Met: {total_demand_met}")
    
    optimal_assignments = {
        demand_truck.loc[i, "demand_node_index"]: demand_truck.loc[i, "truck_node_index"]
        for i in demand_truck.index if x[i].x > 0.5
    }
    
    print("\nOptimal Truck Assignments:")
    for demand, truck in optimal_assignments.items():
        print(f"Demand Node {demand} is served by Truck {truck}")
else:
    print("No optimal solution found.")
# Out:
# Files in directory: ['BAN 675-01_Text Mining_2025Spring-1.pdf', 'Lecture_pandas.ipynb', 'Bank OZK Resume.pdf', 'Budgeting in class(1).ipynb', 'Advt to class (5).ipynb', 'HW 3 (1).xlsx', 'summer_analyst_resume.docx', 'InstallLDBPackage64c-2-1-2-08.zip', 'BAN 630_Chap 7 notes (2).pdf', '1737353558199 (1).docx', 'Pavan Vinay Veesam - Banker Development Program Resume.pdf', '1741330488026.pdf', 'Rougir_Cosmetics_Solution.xlsx', 'MS_SQL_SERVER_Installation_on_Windows-1.docx', 'Install Respondus LockDown Browser (x64c) 663347111 2.pkg', 'CCFBank_Resume.docx', 'Associate Financial Analyst.pdf', 'PavanVinay_Financial_Analyst_Resume (10).pdf', 'BankScheduling (1).ipynb', 'ban612finalprojectsubmissiongroup3', 'BAN 630_Chap 6 (6 slides).pdf', 'Account_Analyst.pdf', 'GMT20241025-010048_Recording.transcript.vtt', 'round1-day1_problem_data.csv', 'annotated-Big%20Data%20Assignment%2001.docx.pdf', 'GMT20241025-010048_Recording.cc.vtt', 'TransMedics_Resume.docx', 'annotated-Case%204.docx.pdf', 'codebasics-movies-db.sql', '630_intro_LP.xlsx', 'PavanVinay_Edited_Resume (3) (1).docx', 'Final_Exam (1).ipynb', 'PavanVinay_Financial_Analyst_Resume (8).docx', 'Resume_PavanVinay_Veesam.pdf', 'Install Respondus LockDown Browser (x64c) 663347111 3.pkg', 'Resume_Financial_Analyst (1).pdf', 'GMT20241018-010406_Recording.transcript (1).vtt', 'GMT20240904-010516_Recording (1).m4a', 'GMT20240918-011014_Recording.cc.vtt', 'PdtMix with SA(1) (2) (1).ipynb', ' Barclays Resume.docx', 'Social Impact Innovation Intern.pdf', '173895233795234 (1).docx', 'Advt.ipynb', 'Financial_Analyst_Resume_PavanVinay (1).docx', 'Rougir_Cosmetics_Solver_Setup.xlsx', 'Crédit Agricole CIB_Resume.docx', 'Data_Mining', 'day1_4.csv', 'Resume_PavanVinayVeesam (10).docx', 'Pavan Vinay Veesam - Intern Resume-cover-letter.pdf', 'ATM and Bumper in class (1).ipynb', 'git-course-2 2', 'BAN630-HW4.ipynb', 'Financial_Analyst_Resume_PavanVinay (3).docx', 'BAN 630_Chap 4 (6).pdf', 'GMT20241018-010406_RecordingnewChat.txt', 'pexels-jonathanschmer-2602599.jpg', 'round1-day1_truck_node_data.csv', 'GMT20240904-010516_RecordingnewChat (1).txt', 'Resume_PavanVinayVeesam (2).docx', 'Graduate_Intern.docx', 'Cover_Letter_Pavan_Vinay_Veesam (1).pdf', 'Data_Analyst_Resume (1).docx', 'PavanVinayVeesam_Financial_Analyst_Resume (1).pdf', 'veesam_pavan_vinay_resume (4) (5).pdf', 'Data Loading.pptx', 'BAN 620_2024_Fall_Syllabus 2-1 (3).pdf', 'day3_4.csv', 'Commercial Credit Analyst Intern .docx', 'HW 1 (1).pdf', 'online_retail_II 7.xlsx', 'CourseOverview-BAN622-1-1.pptx', 'Cover_Letter_Pavan_Vinay_Veesam.pdf', 'Pavan Vinay Veesam Resume-cover-letter.pdf', '1738886721889.docx', 'CV.docx', 'Travel Reservation December 18 for PAVAN VINAY VEESAM (1).pdf', '1737353558199.pdf', 'annotated-BAN%20620%28Data%20mining%29%20final%20project.pdf', 'BAN 620_2024_Fall_Syllabus 2-1.pdf', 'Summer_Intern.docx', 'GMT20241018-010406_Recording_2160x1440.mp4', 'IMG-20250205-WA0003.jpg', 'Advt to class.ipynb', 'BAN 620_Chap14 ARCF.pdf', 'PavanVinayVeesam_Resume.pdf', 'OFA Company Values - Final 8-7-23.pdf', 'NLP.xlsx', 'BAN 620(Data mining) final project (4).ipynb', 'GMT20241018-010406_Recording.m4a', 'Chapter04 (1).pptx', 'GMT20241025-010048_Recording_2160x1440.mp4', 'MS_SQL_SERVER_Installation_on_Mac-1.docx', 'BAN 630_Chap 6 (1).pdf', 'PavanVinay_Edited_Resume (10) (1).pdf', 'GMT20240911-010400_RecordingnewChat.txt', 'chunking.py', 'First Horizon Bank_Resume.docx', 'mysql-workbench-community-8.0.40-macos-arm64.dmg', 'SQL Server Driver for Mac.pkg', 'HW 4 (2).pdf', 'IMG_20250217_111153585.jpg', 'PavanVinay_Edited_Resume (1).pdf', 'Nightwing Resume.docx', 'Pavan Vinay Veesam - Financial Analyst Resume-cover-letter.pdf', 'GMT20240904-010516_Recording_1600x800 (2).mp4', 'Business Recommendations for Hiland.docx', 'Claims Intern.docx', 'Warehouse (3).ipynb', 'Reworld_Waste_Resume.docx', '1234.docx', 'Financial_Analyst_Resume_PavanVinay (13).docx', 'DOC-20250213-WA0006 (2)', 'Case4 (2).ipynb', 'Resume_PavanVinayVeesam.docx', '17387150968 ...
# Columns in problem_data before processing: Index(['burrito_price', 'ingredient_cost', 'truck_cost'], dtype='object')
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 24.3.0 24D81)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 59 rows, 884 columns and 1742 nonzeros
# Model fingerprint: 0xaeb8b31d
# Variable types: 0 continuous, 884 integer (884 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [5e+00, 4e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -3040.000000
# Presolve time: 0.00s
# Presolved: 59 rows, 884 columns, 1742 nonzeros
# Variable types: 0 continuous, 884 integer (884 binary)
#
# Root relaxation: objective 6.730000e+03, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 6730.00000    0   15 -3040.0000 6730.00000   321%     -    0s
# H    0     0                    3230.0000000 6730.00000   108%     -    0s
# H    0     0                    3705.0000000 6730.00000  81.6%     -    0s
# H    0     0                    3950.0000000 6730.00000  70.4%     -    0s
# H    0     0                    4180.0000000 6730.00000  61.0%     -    0s
# H    0     0                    4380.0000000 6730.00000  53.7%     -    0s
#      0     0 5654.08676    0   51 4380.00000 5654.08676  29.1%     -    0s
#      0     0 5638.39019    0   59 4380.00000 5638.39019  28.7%     -    0s
# H    0     0                    4385.0000000 5638.39019  28.6%     -    0s
#      0     0 5063.01516    0   57 4385.00000 5063.01516  15.5%     -    0s
# H    0     0                    4405.0000000 5059.84062  14.9%     -    0s
# H    0     0                    4445.0000000 5059.84062  13.8%     -    0s
#      0     0 5059.84062    0   55 4445.00000 5059.84062  13.8%     -    0s
#      0     0 4888.02216    0   45 4445.00000 4888.02216  10.0%     -    0s
# H    0     0                    4595.0000000 4888.02216  6.38%     -    0s
# H    0     0                    4605.0000000 4888.02216  6.15%     -    0s
# H    0     0                    4645.0000000 4888.02216  5.23%     -    0s
# H    0     0                    4650.0000000 4887.43519  5.11%     -    0s
#      0     0 4887.43519    0   47 4650.00000 4887.43519  5.11%     -    0s
# H    0     0                    4730.0000000 4887.43519  3.33%     -    0s
#      0     0 4839.48589    0   10 4730.00000 4839.48589  2.31%     -    0s
# *    0     0               0    4775.0000000 4775.00000  0.00%     -    0s
#
# Explored 1 nodes (330 simplex iterations) in 0.04 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 4775 4730 4650 ... 4380
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.775000000000e+03, best bound 4.775000000000e+03, gap 0.0000%
# Total Profit: 4775.0
# Total Trucks Used: 6.0
# Total Demand Met: 1255
#
# Optimal Truck Assignments:
# Demand Node demand2 is served by Truck truck12
# Demand Node demand9 is served by Truck truck17
# Demand Node demand11 is served by Truck truck17
# Demand Node demand12 is served by Truck truck12
# Demand Node demand13 is served by Truck truck17
# Demand Node demand14 is served by Truck truck12
# Demand Node demand15 is served by Truck truck23
# Demand Node demand17 is served by Truck truck23
# Demand Node demand18 is served by Truck truck23
# Demand Node demand19 is served by Truck truck23
# Demand Node demand20 is served by Truck truck23
# Demand Node demand21 is served by Truck truck17
# Demand Node demand22 is served by Truck truck17
# Demand Node demand25 is served by Truck truck34
# Demand Node demand26 is served by Truck truck34
# Demand Node demand28 is served by Truck truck23
# Demand Node demand29 is served by Truck truck38
# Demand Node demand31 is served by Truck truck38
# Demand Node demand32 is served by Truck truck38
# Demand Node demand33 is served by Truck truck38
# Demand Node demand34 is served by Truck truck34
# Demand Node demand35 is served by Truck truck34
# Demand Node demand37 is served by Truck truck43
# Demand Node demand38 is served by Truck truck34
# Demand Node demand40 is served by Truck truck43
# Demand Node demand41 is served by Truck truck43
# Demand Node demand45 is served by Truck truck38
# Demand Node demand46 is served by Truck truck38
# Demand Node demand47 is served by Truck truck34
# Demand Node demand48 is served by Truck truck17
# Demand Node demand50 is served by Truck truck17
# Demand Node demand51 is served by Truck truck17
# Demand Node demand53 is served by Truck truck12

# %%
from gurobipy import Model, GRB
import pandas as pd

# Load data from CSV files
demand_nodes = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day3_1.csv")
demand_truck = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day3_3.csv")
problem_data = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day3_2.csv")
truck_nodes = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day3_4.csv")

# Convert truck identifiers to string for consistency
demand_truck['truck_node_index'] = demand_truck['truck_node_index'].astype(str)
truck_nodes['index'] = truck_nodes['index'].astype(str)

# Extract costs and parameters
burrito_price = problem_data['burrito_price'][0]
ingredient_cost = problem_data['ingredient_cost'][0]
truck_cost = problem_data['truck_cost'][0]

# Create a Gurobi Model
model = Model("Optimal_Truck_Location")

# Decision Variables: Assign trucks to demand locations
x = model.addVars(demand_truck.index, vtype=GRB.BINARY, name="assign")  # 1 if demand node is served by truck
y = model.addVars(truck_nodes['index'], vtype=GRB.BINARY, name="use_truck")  # 1 if truck is used

# Objective Function: Maximize Profit
model.setObjective(
    sum(x[i] * ((burrito_price - ingredient_cost) * demand_truck.loc[i, 'scaled_demand']) for i in demand_truck.index)
    - sum(y[j] * truck_cost for j in truck_nodes['index']),  # Truck cost applied only if the truck is used
    GRB.MAXIMIZE
)

# Constraints: Ensure each demand node is served exactly once
for demand in demand_nodes['index']:
    model.addConstr(
        sum(x[i] for i in demand_truck.index if demand_truck.loc[i, 'demand_node_index'] == demand) == 1, 
        name=f"demand_fulfillment_{demand}"
    )

# Ensure that a truck is marked as "used" if it's assigned to at least one demand node
for j in truck_nodes['index']:
    if j in demand_truck['truck_node_index'].values:  # Ensure truck exists in demand_truck dataset
        model.addConstr(
            sum(x[i] for i in demand_truck.index if demand_truck.loc[i, 'truck_node_index'] == j) <= y[j] * len(demand_nodes),
            name=f"truck_usage_{j}"
        )

# Optimize the Model
model.optimize()

# Print the Total Profit
if model.status == GRB.OPTIMAL:
    print(f"Total Profit: {model.ObjVal}")
    
    # Debugging Output: Check how many trucks are used
    total_trucks_used = sum(y[j].x for j in truck_nodes['index'])
    print(f"Total Trucks Used: {total_trucks_used}")
    
    # Check total demand met
    total_demand_met = sum(demand_truck.loc[i, 'scaled_demand'] for i in demand_truck.index if x[i].x > 0.5)
    print(f"Total Demand Met: {total_demand_met}")
    
    optimal_assignments = {
        demand_truck.loc[i, 'demand_node_index']: demand_truck.loc[i, 'truck_node_index']
        for i in demand_truck.index if x[i].x > 0.5
    }
    print("\nOptimal Truck Assignments:")
    for demand, truck in optimal_assignments.items():
        print(f"Demand Node {demand} is served by Truck {truck}")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 24.3.0 24D81)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 59 rows, 884 columns and 1742 nonzeros
# Model fingerprint: 0xa84f7909
# Variable types: 0 continuous, 884 integer (884 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [3e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -3781.000000
# Presolve time: 0.00s
# Presolved: 59 rows, 884 columns, 1742 nonzeros
# Variable types: 0 continuous, 884 integer (884 binary)
#
# Root relaxation: objective 3.947000e+03, 33 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3947.00000    0   15 -3781.0000 3947.00000   204%     -    0s
# H    0     0                     447.0000000 3947.00000   783%     -    0s
# H    0     0                     885.0000000 3947.00000   346%     -    0s
# H    0     0                    1452.0000000 3947.00000   172%     -    0s
# H    0     0                    1518.0000000 3947.00000   160%     -    0s
#      0     0 3338.60423    0   61 1518.00000 3338.60423   120%     -    0s
# H    0     0                    1641.0000000 3338.60423   103%     -    0s
# H    0     0                    1749.0000000 3338.60423  90.9%     -    0s
# H    0     0                    1752.0000000 3338.60423  90.6%     -    0s
# H    0     0                    1825.0000000 3338.60423  82.9%     -    0s
# H    0     0                    1870.0000000 3338.60423  78.5%     -    0s
# H    0     0                    1909.0000000 3338.60423  74.9%     -    0s
#      0     0 3329.38511    0   69 1909.00000 3329.38511  74.4%     -    0s
#      0     0 2933.10426    0   79 1909.00000 2933.10426  53.6%     -    0s
# H    0     0                    2060.0000000 2906.85943  41.1%     -    0s
# H    0     0                    2132.0000000 2906.85943  36.3%     -    0s
#      0     0 2906.85943    0   98 2132.00000 2906.85943  36.3%     -    0s
#      0     0 2667.86247    0   44 2132.00000 2667.86247  25.1%     -    0s
# H    0     0                    2280.0000000 2666.11687  16.9%     -    0s
#      0     0 2666.11687    0   47 2280.00000 2666.11687  16.9%     -    0s
#      0     0 2572.42553    0   26 2280.00000 2572.42553  12.8%     -    0s
# H    0     0                    2468.0000000 2572.42553  4.23%     -    0s
# *    0     0               0    2555.0000000 2555.00000  0.00%     -    0s
#
# Cutting planes:
#   Cover: 49
#   Clique: 52
#   MIR: 26
#   StrongCG: 3
#
# Explored 1 nodes (255 simplex iterations) in 0.10 seconds (0.03 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 2555 2468 2280 ... 1749
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.555000000000e+03, best bound 2.555000000000e+03, gap 0.0000%
# Total Profit: 2555.0
# Total Trucks Used: 4.0
# Total Demand Met: 1185
#
# Optimal Truck Assignments:
# Demand Node demand2 is served by Truck truck14
# Demand Node demand9 is served by Truck truck18
# Demand Node demand11 is served by Truck truck18
# Demand Node demand12 is served by Truck truck14
# Demand Node demand13 is served by Truck truck18
# Demand Node demand14 is served by Truck truck14
# Demand Node demand15 is served by Truck truck14
# Demand Node demand17 is served by Truck truck14
# Demand Node demand18 is served by Truck truck14
# Demand Node demand19 is served by Truck truck14
# Demand Node demand20 is served by Truck truck14
# Demand Node demand21 is served by Truck truck18
# Demand Node demand22 is served by Truck truck18
# Demand Node demand25 is served by Truck truck34
# Demand Node demand26 is served by Truck truck34
# Demand Node demand28 is served by Truck truck38
# Demand Node demand29 is served by Truck truck38
# Demand Node demand31 is served by Truck truck38
# Demand Node demand32 is served by Truck truck38
# Demand Node demand33 is served by Truck truck38
# Demand Node demand34 is served by Truck truck34
# Demand Node demand35 is served by Truck truck34
# Demand Node demand37 is served by Truck truck34
# Demand Node demand38 is served by Truck truck34
# Demand Node demand40 is served by Truck truck34
# Demand Node demand41 is served by Truck truck38
# Demand Node demand45 is served by Truck truck38
# Demand Node demand46 is served by Truck truck38
# Demand Node demand47 is served by Truck truck34
# Demand Node demand48 is served by Truck truck18
# Demand Node demand50 is served by Truck truck38
# Demand Node demand51 is served by Truck truck18
# Demand Node demand53 is served by Truck truck18

# %%
from gurobipy import Model, GRB
import pandas as pd

# Load data from CSV files
demand_nodes = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day4_1.csv")
demand_truck = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day4_3.csv")
problem_data = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day4_2.csv")
truck_nodes = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day4_4.csv")

# Convert truck identifiers to string for consistency
demand_truck['truck_node_index'] = demand_truck['truck_node_index'].astype(str)
truck_nodes['index'] = truck_nodes['index'].astype(str)

# Extract costs and parameters
burrito_price = problem_data['burrito_price'][0]
ingredient_cost = problem_data['ingredient_cost'][0]
truck_cost = problem_data['truck_cost'][0]

# Create a Gurobi Model
model = Model("Optimal_Truck_Location")

# Decision Variables: Assign trucks to demand locations
x = model.addVars(demand_truck.index, vtype=GRB.BINARY, name="assign")  # 1 if demand node is served by truck
y = model.addVars(truck_nodes['index'], vtype=GRB.BINARY, name="use_truck")  # 1 if truck is used

# Objective Function: Maximize Profit
model.setObjective(
    sum(x[i] * ((burrito_price - ingredient_cost) * demand_truck.loc[i, 'scaled_demand']) for i in demand_truck.index)
    - sum(y[j] * truck_cost for j in truck_nodes['index']),  # Truck cost applied only if the truck is used
    GRB.MAXIMIZE
)

# Constraints: Ensure each demand node is served exactly once
for demand in demand_nodes['index']:
    model.addConstr(
        sum(x[i] for i in demand_truck.index if demand_truck.loc[i, 'demand_node_index'] == demand) == 1, 
        name=f"demand_fulfillment_{demand}"
    )

# Ensure that a truck is marked as "used" if it's assigned to at least one demand node
for j in truck_nodes['index']:
    if j in demand_truck['truck_node_index'].values:  # Ensure truck exists in demand_truck dataset
        model.addConstr(
            sum(x[i] for i in demand_truck.index if demand_truck.loc[i, 'truck_node_index'] == j) <= y[j] * len(demand_nodes),
            name=f"truck_usage_{j}"
        )

# Optimize the Model
model.optimize()

# Print the Total Profit
if model.status == GRB.OPTIMAL:
    print(f"Total Profit: {model.ObjVal}")
    
    # Debugging Output: Check how many trucks are used
    total_trucks_used = sum(y[j].x for j in truck_nodes['index'])
    print(f"Total Trucks Used: {total_trucks_used}")
    
    # Check total demand met
    total_demand_met = sum(demand_truck.loc[i, 'scaled_demand'] for i in demand_truck.index if x[i].x > 0.5)
    print(f"Total Demand Met: {total_demand_met}")
    
    optimal_assignments = {
        demand_truck.loc[i, 'demand_node_index']: demand_truck.loc[i, 'truck_node_index']
        for i in demand_truck.index if x[i].x > 0.5
    }
    print("\nOptimal Truck Assignments:")
    for demand, truck in optimal_assignments.items():
        print(f"Demand Node {demand} is served by Truck {truck}")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 24.3.0 24D81)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 59 rows, 884 columns and 1742 nonzeros
# Model fingerprint: 0x36244d3d
# Variable types: 0 continuous, 884 integer (884 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+01]
#   Objective range  [5e+00, 3e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -4635.000000
# Presolve time: 0.00s
# Presolved: 59 rows, 884 columns, 1742 nonzeros
# Variable types: 0 continuous, 884 integer (884 binary)
#
# Root relaxation: objective 3.545000e+03, 36 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3545.00000    0   15 -4635.0000 3545.00000   176%     -    0s
# H    0     0                      45.0000000 3545.00000  7778%     -    0s
# H    0     0                     190.0000000 3545.00000  1766%     -    0s
# H    0     0                     265.0000000 3545.00000  1238%     -    0s
# H    0     0                     680.0000000 1773.90066   161%     -    0s
# H    0     0                     730.0000000 1773.90066   143%     -    0s
#      0     0 1773.90066    0   18  730.00000 1773.90066   143%     -    0s
# H    0     0                     960.0000000 1773.90066  84.8%     -    0s
# H    0     0                     970.0000000 1727.35887  78.1%     -    0s
# H    0     0                    1210.0000000 1727.35887  42.8%     -    0s
#      0     0 1419.51613    0   19 1210.00000 1419.51613  17.3%     -    0s
# H    0     0                    1230.0000000 1419.51613  15.4%     -    0s
# H    0     0                    1255.0000000 1419.51613  13.1%     -    0s
#      0     0 1327.09189    0    4 1255.00000 1327.09189  5.74%     -    0s
#      0     0     cutoff    0      1255.00000 1255.00000  0.00%     -    0s
#
# Explored 1 nodes (266 simplex iterations) in 0.03 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 1255 1255 1230 ... 265
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.255000000000e+03, best bound 1.255000000000e+03, gap 0.0000%
# Total Profit: 1255.0
# Total Trucks Used: 7.0
# Total Demand Met: 601
#
# Optimal Truck Assignments:
# Demand Node demand2 is served by Truck truck12
# Demand Node demand9 is served by Truck truck18
# Demand Node demand11 is served by Truck truck16
# Demand Node demand12 is served by Truck truck38
# Demand Node demand13 is served by Truck truck16
# Demand Node demand14 is served by Truck truck41
# Demand Node demand15 is served by Truck truck23
# Demand Node demand17 is served by Truck truck23
# Demand Node demand18 is served by Truck truck23
# Demand Node demand19 is served by Truck truck23
# Demand Node demand20 is served by Truck truck23
# Demand Node demand21 is served by Truck truck16
# Demand Node demand22 is served by Truck truck18
# Demand Node demand25 is served by Truck truck41
# Demand Node demand26 is served by Truck truck41
# Demand Node demand28 is served by Truck truck23
# Demand Node demand29 is served by Truck truck23
# Demand Node demand31 is served by Truck truck38
# Demand Node demand32 is served by Truck truck37
# Demand Node demand33 is served by Truck truck37
# Demand Node demand34 is served by Truck truck18
# Demand Node demand35 is served by Truck truck41
# Demand Node demand37 is served by Truck truck41
# Demand Node demand38 is served by Truck truck23
# Demand Node demand40 is served by Truck truck23
# Demand Node demand41 is served by Truck truck41
# Demand Node demand45 is served by Truck truck38
# Demand Node demand46 is served by Truck truck38
# Demand Node demand47 is served by Truck truck38
# Demand Node demand48 is served by Truck truck18
# Demand Node demand50 is served by Truck truck41
# Demand Node demand51 is served by Truck truck18
# Demand Node demand53 is served by Truck truck12

# %%
from gurobipy import Model, GRB
import pandas as pd

# Load data from CSV files
demand_nodes = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day5_1.csv")
demand_truck = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day5_3.csv")
problem_data = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day5_2.csv")
truck_nodes = pd.read_csv(r"/Users/pavanvinayveesam/downloads/day5_4.csv")

# Convert truck identifiers to string for consistency
demand_truck['truck_node_index'] = demand_truck['truck_node_index'].astype(str)
truck_nodes['index'] = truck_nodes['index'].astype(str)

# Extract costs and parameters
burrito_price = problem_data['burrito_price'][0]
ingredient_cost = problem_data['ingredient_cost'][0]
truck_cost = problem_data['truck_cost'][0]

# Create a Gurobi Model
model = Model("Optimal_Truck_Location")

# Decision Variables: Assign trucks to demand locations
x = model.addVars(demand_truck.index, vtype=GRB.BINARY, name="assign")  # 1 if demand node is served by truck
y = model.addVars(truck_nodes['index'], vtype=GRB.BINARY, name="use_truck")  # 1 if truck is used

# Objective Function: Maximize Profit
model.setObjective(
    sum(x[i] * ((burrito_price - ingredient_cost) * demand_truck.loc[i, 'scaled_demand']) for i in demand_truck.index)
    - sum(y[j] * truck_cost for j in truck_nodes['index']),  # Truck cost applied only if the truck is used
    GRB.MAXIMIZE
)

# Constraints: Ensure each demand node is served exactly once
for demand in demand_nodes['index']:
    model.addConstr(
        sum(x[i] for i in demand_truck.index if demand_truck.loc[i, 'demand_node_index'] == demand) == 1, 
        name=f"demand_fulfillment_{demand}"
    )

# Ensure that a truck is marked as "used" if it's assigned to at least one demand node
for j in truck_nodes['index']:
    if j in demand_truck['truck_node_index'].values:  # Ensure truck exists in demand_truck dataset
        model.addConstr(
            sum(x[i] for i in demand_truck.index if demand_truck.loc[i, 'truck_node_index'] == j) <= y[j] * len(demand_nodes),
            name=f"truck_usage_{j}"
        )

# Optimize the Model
model.optimize()

# Print the Total Profit
if model.status == GRB.OPTIMAL:
    print(f"Total Profit: {model.ObjVal}")
    
    # Debugging Output: Check how many trucks are used
    total_trucks_used = sum(y[j].x for j in truck_nodes['index'])
    print(f"Total Trucks Used: {total_trucks_used}")
    
    # Check total demand met
    total_demand_met = sum(demand_truck.loc[i, 'scaled_demand'] for i in demand_truck.index if x[i].x > 0.5)
    print(f"Total Demand Met: {total_demand_met}")
    
    optimal_assignments = {
        demand_truck.loc[i, 'demand_node_index']: demand_truck.loc[i, 'truck_node_index']
        for i in demand_truck.index if x[i].x > 0.5
    }
    print("\nOptimal Truck Assignments:")
    for demand, truck in optimal_assignments.items():
        print(f"Demand Node {demand} is served by Truck {truck}")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (mac64[arm] - Darwin 24.3.0 24D81)
#
# CPU model: Apple M3
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 110 rows, 3080 columns and 6104 nonzeros
# Model fingerprint: 0x633c79fc
# Variable types: 0 continuous, 3080 integer (3080 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   Objective range  [5e+00, 4e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -6540.000000
# Presolve time: 0.00s
# Presolved: 110 rows, 3080 columns, 6104 nonzeros
# Variable types: 0 continuous, 3080 integer (3080 binary)
#
# Root relaxation: objective 1.127000e+04, 54 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 11270.0000    0   29 -6540.0000 11270.0000   272%     -    0s
# H    0     0                    4270.0000000 11270.0000   164%     -    0s
# H    0     0                    5800.0000000 11270.0000  94.3%     -    0s
# H    0     0                    7000.0000000 11270.0000  61.0%     -    0s
# H    0     0                    7005.0000000 11270.0000  60.9%     -    0s
# H    0     0                    7055.0000000 11270.0000  59.7%     -    0s
# H    0     0                    7090.0000000 11270.0000  59.0%     -    0s
# H    0     0                    7190.0000000 11270.0000  56.7%     -    0s
# H    0     0                    7235.0000000 11270.0000  55.8%     -    0s
# H    0     0                    7320.0000000 11270.0000  54.0%     -    0s
#      0     0 10519.9674    0   54 7320.00000 10519.9674  43.7%     -    0s
# H    0     0                    7485.0000000 10519.9674  40.5%     -    0s
# H    0     0                    7505.0000000 10519.9674  40.2%     -    0s
# H    0     0                    7510.0000000 10519.9674  40.1%     -    0s
# H    0     0                    7525.0000000 10519.9674  39.8%     -    0s
# H    0     0                    7540.0000000 10519.9674  39.5%     -    0s
# H    0     0                    7545.0000000 10519.9674  39.4%     -    0s
# H    0     0                    7565.0000000 10519.9674  39.1%     -    0s
# H    0     0                    7580.0000000 10518.5396  38.8%     -    0s
#      0     0 10518.5396    0   60 7580.00000 10518.5396  38.8%     -    0s
#      0     0 9441.68688    0  125 7580.00000 9441.68688  24.6%     -    0s
#      0     0 9398.06020    0  152 7580.00000 9398.06020  24.0%     -    0s
#      0     0 8664.59516    0  143 7580.00000 8664.59516  14.3%     -    0s
#      0     0 8587.10006    0  151 7580.00000 8587.10006  13.3%     -    0s
#      0     0 8586.31575    0  152 7580.00000 8586.31575  13.3%     -    0s
#      0     0 8135.01169    0  108 7580.00000 8135.01169  7.32%     -    0s
#      0     0 8112.16268    0  101 7580.00000 8112.16268  7.02%     -    0s
#      0     0 8105.01154    0  108 7580.00000 8105.01154  6.93%     -    0s
#      0     0 8104.97047    0  107 7580.00000 8104.97047  6.93%     -    0s
# H    0     0                    7670.0000000 7850.00000  2.35%     -    0s
# H    0     0                    7675.0000000 7850.00000  2.28%     -    0s
# *    0     0               0    7850.0000000 7850.00000  0.00%     -    0s
#
# Cutting planes:
#   Cover: 111
#   Clique: 82
#   MIR: 51
#   StrongCG: 5
#
# Explored 1 nodes (515 simplex iterations) in 0.15 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 7850 7675 7670 ... 7505
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.850000000000e+03, best bound 7.850000000000e+03, gap 0.0000%
# Total Profit: 7850.0
# Total Trucks Used: 9.0
# Total Demand Met: 2020
#
# Optimal Truck Assignments:
# Demand Node demand0 is served by Truck truck7
# Demand Node demand1 is served by Truck truck7
# Demand Node demand2 is served by Truck truck7
# Demand Node demand3 is served by Truck truck3
# Demand Node demand4 is served by Truck truck3
# Demand Node demand5 is served by Truck truck3
# Demand Node demand6 is served by Truck truck21
# Demand Node demand7 is served by Truck truck21
# Demand Node demand8 is served by Truck truck3
# Demand Node demand9 is served by Truck truck21
# Demand Node demand10 is served by Truck truck21
# Demand Node demand11 is served by Truck truck15
# Demand Node demand12 is served by Truck truck15
# Demand Node demand13 is served by Truck truck15
# Demand Node demand14 is served by Truck truck15
# Demand Node demand15 is served by Truck truck7
# Demand Node demand16 is served by Truck truck7
# Demand Node demand17 is served by Truck truck26
# Demand Node demand18 is served by Truck truck15
# Demand Node demand19 is served by Truck truck26
# Demand Node demand20 is served by Truck truck15
# Demand Node demand21 is served by Truck truck15
# Demand Node demand22 is served by Truck truck56
# Demand Node demand23 is served by Truck truck56
# Demand Node demand24 is served by Truck truck56
# Demand Node demand25 is served by Truck truck56
# Demand Node demand26 is served by Truck truck56
# Demand Node demand27 is served by Truck truck28
# Demand Node demand28 is served by Truck truck26
# Demand Node demand29 is served by Truck truck26
# Demand Node demand30 is served by Truck truck26
# Demand Node demand31 is served by Truck truck26
# Demand Node demand32 is served by Truck truck28
# Demand Node demand33 is served by Truck truck28
# Demand Node demand34 is served by Truck truck56
# Demand Node demand35 is served by Truck truck56
# Demand Node demand36 is served by Truck truck45
# Demand Node demand37 is served by Truck truck45
# Demand Node demand38 is served by Truck truck45
# Demand Node demand39 is served by Truck truck45
# Demand Node demand40 is served by Truck truck45
# Demand Node demand41 is served by Truck truck40
# Demand Node demand42 is served by Truck truck40
# Demand Node demand43 is served by Truck truck40
# Demand Node demand44 is served by Truck truck40
# Demand Node demand45 is served by Truck truck40
# Demand Node demand46 is served by Truck truck40
# Demand Node demand47 is served by Truck truck45
# Demand Node demand48 is served by Truck truck56
# Demand Node demand49 is served by Truck truck45
# Demand Node demand50 is served by Truck truck26
# Demand Node demand51 is served by Truck truck21
# Demand Node demand52 is served by Truck truck7
# Demand Node demand53 is served by Truck truck15
